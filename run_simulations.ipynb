# %%
# %load_ext autoreload
# %autoreload 2

from mcmc import *
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_name = 'numba_test'

# %%
temperatures = np.linspace(0.5, 3, 20)

# %%
sim_data = run_simulation(200, 2000, temperatures, 5)

# %%
plot_results(sim_data, temperatures, test_name, save=True)
