# %%
# %load_ext autoreload
# %autoreload 2

from mcmc import run_simulation, plot_results
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_name = 'numba_test'

# %%
temperatures = np.linspace(0.2, 10, 50)

# %%
sim_data = run_simulation(100, 2000, temperatures, 10)

# %%
plot_results(sim_data, temperatures, test_name, save=True)
