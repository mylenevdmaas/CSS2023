# %% [markdown]
# ### Recreating Popiel et al. (2020) figures on 5 node network

# %%
from mcmc import run_simulation, plot_results
import numpy as np
import matplotlib.pyplot as plt

# %%
sim_name = 'basic_5_nodes'

# %%
temperatures = np.linspace(0.1, 3, 50)
size = 5

# %%
sim_data = run_simulation(1000, 2000, temperatures, size)
plot_results(sim_data, temperatures, sim_name, save=True, figsize=[8,3])
